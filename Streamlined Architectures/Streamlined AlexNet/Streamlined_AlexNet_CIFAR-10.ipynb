# %% [markdown]
# # AlexNet Implementation and Training from Scratch with CIFAR 10

# %% [markdown]
# ## Imported Libraries

# %%
import os
import random
import numpy
import matplotlib.pyplot
import sklearn.model_selection
import sklearn.metrics

import torch
import torchvision
import collections

# %% [markdown]
# RNG Seed Setting

# %%
"""
-The seed provides a starting point for generating a series of random numbers.
-In relation to this AlexNet, the seed provides a starting point for selecting
 a series of filters and weights for the neural network for training. This
 eliminates the randomness of results produced by the training of the network.
-In essence, this allows others to reproduce your results exactly by utilizing
 the same seed.
"""

# set the overall seed here
rnd_seed = 2025

os.environ["CUBLAS_WORKSPACE_CONFIG"] = ":16:8"

random.seed(rnd_seed)
numpy.random.seed(rnd_seed)

torch.manual_seed(rnd_seed)
torch.cuda.manual_seed(rnd_seed)
torch.cuda.manual_seed_all(rnd_seed)

torch.backends.cudnn.benchmark = False
torch.backends.cudnn.deterministic = True
torch.use_deterministic_algorithms(True)

data_generator = torch.Generator().manual_seed(rnd_seed)

# if multiple python workers are eventually used...
def worker_init_fn(worker_id):
    random.seed(rnd_seed + worker_id)
    numpy.random.seed(rnd_seed + worker_id)

# %% [markdown]
# ## On GPU balanced accuracy computation

# %%
def torch_compute_bacc(preds: torch.Tensor, labels: torch.Tensor, class_count: int):
    recall_per_class = []

    for label in range(class_count):
        true_positive = ((preds == label) & (labels == label)).sum().float()
        total_actual = (labels == label).sum().float()

        recall = true_positive / total_actual if total_actual > 0.0 else torch.tensor(0.0)
        recall_per_class.append(recall)

    return torch.stack(recall_per_class).mean().item()

# %% [markdown]
# ## CIFAR 10 Download and Preparation

# %%
"""
-Class count: defines number of possible classes for each image to be classified.
-Batch size:  the number of images loaded into the GPU for training at a time.
-Image size:  a n x n pixel size of each input image.
-Validation split (val_split): from the original training partion of data, a decimal value
                               that takes a portion of the training partion to simulate a
                               test partion. Here, it is 0.2 so 20% of the training data
                               will be used to simulate testing. Basically like a quiz.
"""

# CIFAR-10 configuration
class_count = 10 # 10 classes in CIFAR 10
batch_size = 256
image_size = 224
val_split = 0.2

# %%
# Dataset stats saved to a npz file
# Load the saved statistical information as tensors
# See original architectures for more details
data_stats = numpy.load("CIFAR10_stats.npz")
mean = torch.tensor(data_stats['mean'], dtype=torch.float)
std = torch.tensor(data_stats['stdev'], dtype=torch.float)
label_weights = torch.tensor(data_stats['lw'], dtype=torch.float)

# %%
# data loading
# train and test transforms/augmentations
train_transform = torchvision.transforms.Compose([
    torchvision.transforms.Resize(image_size),
    torchvision.transforms.RandomCrop(image_size),
    torchvision.transforms.RandomHorizontalFlip(),
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize(mean=mean, std=std)
])

""" Do not apply augmentations to testing """
test_transform = torchvision.transforms.Compose([
    torchvision.transforms.Resize(image_size),
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize(mean=mean, std=std)
])

# train vs. validation split, creates the "quiz partition"
train_val_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, \
                                                 transform=train_transform)
train_targets = train_val_dataset.targets
splitter = sklearn.model_selection.StratifiedShuffleSplit(n_splits=1, test_size=val_split, random_state=rnd_seed)
train_idx, val_idx = next(splitter.split(numpy.zeros(len(train_targets)), train_targets))

train_dataset = torch.utils.data.Subset(train_val_dataset, train_idx)
val_dataset = torch.utils.data.Subset(train_val_dataset, val_idx)
test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=test_transform)

# actual data loading for each partition, training, quiz, and test
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True, \
                                           generator=data_generator)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, shuffle=False, \
                                         generator=data_generator)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False, \
                                          generator=data_generator)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ## AlexNet Implementation

# %%
"""
Implementation based on: https://proceedings.neurips.cc/paper_files/paper/2012/file/c399862d3b9d6b76c8436e924a68c45b-Paper.pdf

See Figure 2
"""

# See alexnet_class.py
from alexnet_class import AlexNet

# %% [markdown]
# ## Network Training

# %%
# training configuration
gpu="0" # change as required for your GPU

"""
-Learning rate (lr) - Given the need to minimize the loss, gradient descent enables
                      enables us to find only the direction of minimization, but not
                      how much we should move toward that direction, which is where lr comes
                      into play (start large, decrease with time).
-Momentum           - Insists on the use of moving toward a single direction, the value represents
                      the insistance (0 < m < 1), the closer to 1, the stronger the insistance.
-Weight decay       - Regularization factor, limits the ability to adjust connection weights
                      during backpropagation with each step. Avoids overfitting.
-Max epochs         - Maximum amount of times backpropagation is conducted.
-Patience           - Determines when to stop learning on a certain models after n failed attempts and
                      revert to the most successful model.
"""

# AlexNet used these parameters to train
lr = 0.01
momentum = 0.9
w_decay=0.0005

max_epochs = 100
patience = 10

# %%
# training preparation
device = torch.device("cuda:" + gpu if torch.cuda.is_available() else "cpu")
model = AlexNet(class_count=class_count).to(device)
label_weights = label_weights.to(device)
# Computes the loss with every step
criterion = torch.nn.CrossEntropyLoss(weight=label_weights)
# Mini batch stochastic gradient descent
optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum=momentum, weight_decay=w_decay)

# training stop control
best_bacc = float('-inf')
# Reduce patience count with every failure
patience_count = patience

# training loop
for epoch in range(max_epochs):
    # train
    model.train()
    train_loss, train_preds, train_labels = 0.0, [], []

    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        # Once loss computed, start backpropagation process
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = outputs.max(1)

        train_preds.append(predicted)
        train_labels.append(labels)

    train_preds = torch.cat(train_preds)
    train_labels = torch.cat(train_labels)

    # Compute balanced accuracy, recalculate loss
    train_bacc = torch_compute_bacc(train_preds, train_labels, class_count)
    train_loss /= len(train_loader)

    # validation
    model.eval()
    val_loss, val_preds, val_labels = 0.0, [], []

    with torch.no_grad():
        # Same training process as training partition, but without backpropagation
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)

            val_loss += criterion(outputs, labels).item()
            _, predicted = outputs.max(1)

            val_preds.append(predicted)
            val_labels.append(labels)

    val_preds = torch.cat(val_preds)
    val_labels = torch.cat(val_labels)

    val_bacc = torch_compute_bacc(val_preds, val_labels, class_count)
    val_loss /= len(val_loader)

    print(f"Epoch {epoch + 1}: Train Loss={train_loss:.4f}, Train BAcc={train_bacc * 100.0:.2f}%, \
          Val Loss={val_loss:.4f}, Val BAcc={val_bacc * 100.0:.2f}%, Patience={patience_count}")

    # check patience, early stop if balanced accuracy gets worse
    if val_bacc > best_bacc:
        best_bacc = val_bacc
        torch.save(model.state_dict(), "alexnet_cifar10_model.pth")
        patience_count = patience
    else:
        patience_count -= 1
        if patience_count <= 0:
            print(f"Balanced accuracy got worse for {patience} consecutive times; stopping early.")
            break
# Out:
# Epoch 1: Train Loss=2.2000, Train BAcc=16.44%,           Val Loss=1.9123, Val BAcc=28.25%, Patience=10
# Epoch 2: Train Loss=1.7045, Train BAcc=37.26%,           Val Loss=1.6317, Val BAcc=42.48%, Patience=10
# Epoch 3: Train Loss=1.4451, Train BAcc=47.13%,           Val Loss=1.4025, Val BAcc=49.55%, Patience=10
# Epoch 4: Train Loss=1.2961, Train BAcc=53.27%,           Val Loss=1.1903, Val BAcc=57.59%, Patience=10
# Epoch 5: Train Loss=1.1352, Train BAcc=59.42%,           Val Loss=1.1434, Val BAcc=59.85%, Patience=10
# Epoch 6: Train Loss=0.9941, Train BAcc=64.73%,           Val Loss=1.0004, Val BAcc=65.99%, Patience=10
# Epoch 7: Train Loss=0.8843, Train BAcc=69.03%,           Val Loss=0.8325, Val BAcc=71.48%, Patience=10
# Epoch 8: Train Loss=0.8011, Train BAcc=72.00%,           Val Loss=0.8088, Val BAcc=72.88%, Patience=10
# Epoch 9: Train Loss=0.7156, Train BAcc=75.17%,           Val Loss=0.7921, Val BAcc=73.37%, Patience=10
# Epoch 10: Train Loss=0.6845, Train BAcc=76.36%,           Val Loss=0.7255, Val BAcc=75.03%, Patience=10
# Epoch 11: Train Loss=0.6263, Train BAcc=78.40%,           Val Loss=0.7066, Val BAcc=75.94%, Patience=10
# Epoch 12: Train Loss=0.5776, Train BAcc=80.04%,           Val Loss=0.5974, Val BAcc=79.63%, Patience=10
# Epoch 13: Train Loss=0.5417, Train BAcc=81.37%,           Val Loss=0.6348, Val BAcc=77.87%, Patience=10
# Epoch 14: Train Loss=0.4982, Train BAcc=82.85%,           Val Loss=0.5631, Val BAcc=80.64%, Patience=9
# Epoch 15: Train Loss=0.4732, Train BAcc=83.54%,           Val Loss=0.5457, Val BAcc=81.20%, Patience=10
# Epoch 16: Train Loss=0.4311, Train BAcc=85.07%,           Val Loss=0.5409, Val BAcc=81.40%, Patience=10
# Epoch 17: Train Loss=0.4053, Train BAcc=85.83%,           Val Loss=0.5278, Val BAcc=82.67%, Patience=10
# Epoch 18: Train Loss=0.3779, Train BAcc=86.98%,           Val Loss=0.5439, Val BAcc=82.05%, Patience=10
# Epoch 19: Train Loss=0.3637, Train BAcc=87.24%,           Val Loss=0.4974, Val BAcc=83.37%, Patience=9
# Epoch 20: Train Loss=0.3354, Train BAcc=88.32%,           Val Loss=0.4944, Val BAcc=83.80%, Patience=10
# Epoch 21: Train Loss=0.3169, Train BAcc=89.00%,           Val Loss=0.4587, Val BAcc=84.18%, Patience=10
# Epoch 22: Train Loss=0.2938, Train BAcc=89.73%,           Val Loss=0.5538, Val BAcc=83.05%, Patience=10
# Epoch 23: Train Loss=0.2878, Train BAcc=89.97%,           Val Loss=0.5383, Val BAcc=82.95%, Patience=9
# Epoch 24: Train Loss=0.2616, Train BAcc=90.88%,           Val Loss=0.4446, Val BAcc=85.81%, Patience=8
# Epoch 25: Train Loss=0.2346, Train BAcc=91.80%,           Val Loss=0.4586, Val BAcc=85.38%, Patience=10
# Epoch 26: Train Loss=0.2297, Train BAcc=91.93%,           Val Loss=0.4757, Val BAcc=84.95%, Patience=9
# Epoch 27: Train Loss=0.2102, Train BAcc=92.60%,           Val Loss=0.4801, Val BAcc=85.18%, Patience=8
# Epoch 28: Train Loss=0.1957, Train BAcc=93.23%,           Val Loss=0.4843, Val BAcc=85.61%, Patience=7
# Epoch 29: Train Loss=0.1848, Train BAcc=93.63%,           Val Loss=0.4782, Val BAcc=85.57%, Patience=6
# Epoch 30: Train Loss=0.1716, Train BAcc=94.13%,           Val Loss=0.5017, Val BAcc=85.34%, Patience=5
# Epoch 31: Train Loss=0.1622, Train BAcc=94.36%,           Val Loss=0.4940, Val BAcc=85.17%, Patience=4
# Epoch 32: Train Loss=0.1640, Train BAcc=94.40%,           Val Loss=0.5149, Val BAcc=85.25%, Patience=3
# Epoch 33: Train Loss=0.1468, Train BAcc=94.84%,           Val Loss=0.4580, Val BAcc=85.90%, Patience=2
# Epoch 34: Train Loss=0.1342, Train BAcc=95.17%,           Val Loss=0.5058, Val BAcc=85.79%, Patience=10
# Epoch 35: Train Loss=0.1362, Train BAcc=95.31%,           Val Loss=0.5100, Val BAcc=85.42%, Patience=9
# Epoch 36: Train Loss=0.1174, Train BAcc=95.82%,           Val Loss=0.5285, Val BAcc=86.53%, Patience=8
# Epoch 37: Train Loss=0.1250, Train BAcc=95.68%,           Val Loss=0.4873, Val BAcc=86.18%, Patience=10
# Epoch 38: Train Loss=0.1163, Train BAcc=95.90%,           Val Loss=0.5085, Val BAcc=86.17%, Patience=9
# Epoch 39: Train Loss=0.1044, Train BAcc=96.41%,           Val Loss=0.5533, Val BAcc=86.29%, Patience=8
# Epoch 40: Train Loss=0.1026, Train BAcc=96.38%,           Val Loss=0.5171, Val BAcc=86.00%, Patience=7
# Epoch 41: Train Loss=0.0984, Train BAcc=96.73%,           Val Loss=0.5469, Val BAcc=85.20%, Patience=6
# Epoch 42: Train Loss=0.1026, Train BAcc=96.41%,           Val Loss=0.5517, Val BAcc=86.35%, Patience=5
# Epoch 43: Train Loss=0.0898, Train BAcc=96.87%,           Val Loss=0.4984, Val BAcc=86.90%, Patience=4
# Epoch 44: Train Loss=0.0788, Train BAcc=97.26%,           Val Loss=0.5281, Val BAcc=86.93%, Patience=10
# Epoch 45: Train Loss=0.0763, Train BAcc=97.46%,           Val Loss=0.4951, Val BAcc=86.96%, Patience=10
# Epoch 46: Train Loss=0.0768, Train BAcc=97.39%,           Val Loss=0.5145, Val BAcc=86.55%, Patience=10
# Epoch 47: Train Loss=0.0771, Train BAcc=97.46%,           Val Loss=0.5239, Val BAcc=86.60%, Patience=9
# Epoch 48: Train Loss=0.0725, Train BAcc=97.61%,           Val Loss=0.5081, Val BAcc=87.24%, Patience=8
# Epoch 49: Train Loss=0.0671, Train BAcc=97.73%,           Val Loss=0.5745, Val BAcc=86.47%, Patience=10
# Epoch 50: Train Loss=0.0674, Train BAcc=97.68%,           Val Loss=0.5459, Val BAcc=86.22%, Patience=9
# Epoch 51: Train Loss=0.0622, Train BAcc=97.87%,           Val Loss=0.5271, Val BAcc=86.73%, Patience=8
# Epoch 52: Train Loss=0.0647, Train BAcc=97.77%,           Val Loss=0.5576, Val BAcc=86.82%, Patience=7
# Epoch 53: Train Loss=0.0661, Train BAcc=97.71%,           Val Loss=0.5236, Val BAcc=86.73%, Patience=6
# Epoch 54: Train Loss=0.0586, Train BAcc=98.01%,           Val Loss=0.5411, Val BAcc=86.39%, Patience=5
# Epoch 55: Train Loss=0.0552, Train BAcc=98.10%,           Val Loss=0.5113, Val BAcc=87.57%, Patience=4
# Epoch 56: Train Loss=0.0510, Train BAcc=98.20%,           Val Loss=0.5448, Val BAcc=86.89%, Patience=10
# Epoch 57: Train Loss=0.0524, Train BAcc=98.22%,           Val Loss=0.5360, Val BAcc=87.46%, Patience=9
# Epoch 58: Train Loss=0.0486, Train BAcc=98.32%,           Val Loss=0.5772, Val BAcc=87.11%, Patience=8
# Epoch 59: Train Loss=0.0592, Train BAcc=98.03%,           Val Loss=0.5395, Val BAcc=86.28%, Patience=7
# Epoch 60: Train Loss=0.0517, Train BAcc=98.32%,           Val Loss=0.5727, Val BAcc=86.50%, Patience=6
# Epoch 61: Train Loss=0.0452, Train BAcc=98.49%,           Val Loss=0.5273, Val BAcc=87.23%, Patience=5
# Epoch 62: Train Loss=0.0473, Train BAcc=98.39%,           Val Loss=0.5639, Val BAcc=87.25%, Patience=4
# Epoch 63: Train Loss=0.0418, Train BAcc=98.53%,           Val Loss=0.5537, Val BAcc=87.15%, Patience=3
# Epoch 64: Train Loss=0.0422, Train BAcc=98.58%,           Val Loss=0.5371, Val BAcc=87.18%, Patience=2
# Epoch 65: Train Loss=0.0376, Train BAcc=98.74%,           Val Loss=0.5642, Val BAcc=86.45%, Patience=1
# Balanced accuracy got worse for 10 consecutive times; stopping early.

# %% [markdown]
# ## Network Evaluation

# %%
# loads the saved model
model.load_state_dict(torch.load('alexnet_cifar10_model.pth'))

# evaluates on the test partition
model.eval()
test_preds, test_labels = [], []

with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = outputs.max(1)

        test_preds.append(predicted)
        test_labels.append(labels)

test_preds = torch.cat(test_preds)
test_labels = torch.cat(test_labels)

test_bacc = torch_compute_bacc(test_preds, test_labels, class_count)
print(f"Test Balanced Accuracy: {test_bacc * 100.0:.2f}%")
# Out:
# Test Balanced Accuracy: 86.83%

# %%
# confusion matrix
cm = sklearn.metrics.confusion_matrix(test_labels.cpu(), test_preds.cpu())
disp = sklearn.metrics.ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap='Blues')
matplotlib.pyplot.title("Confusion Matrix")
matplotlib.pyplot.show()
